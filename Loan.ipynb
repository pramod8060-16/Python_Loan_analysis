# %%
import pandas as pd

# %%
df = pd.read_csv("C:/D/Ethive/assignment/Python_projects/Loan_data_analysis_project/Loan_dataset.csv")
df
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
Dataset : Loan_Data 
Domain : Finance 
Analyse the data and give the answers of 
below questions : 
1.What is the average current loan amount for 
each loan status? 
2.How does the credit score vary with the annual 
income? 
3.Is there a correlation between the number of 
open accounts and the current credit balance? 
4.What is the distribution of credit scores across 
different home ownership types? 
5.How does the annual income differ for different 
purposes of loans? 
6.What is the average monthly debt for each term 
(short-term vs. long-term)? 
7.Is there a correlation between years of credit 
history and the current credit balance? 
8.How does the credit score vary with the years in 
the current job? 
9.What is the relationship between the number of 
credit problems and the number of open 
accounts? 
10.What is the distribution of annual income 
across different loan statuses? 
11.Is there a correlation between the current loan 
amount and the number of open accounts? 
12.How does the monthly debt vary with the 
years of credit history? 
13.What is the average annual income for each 
purpose of loan? 
14.How does the credit score vary with the 
number of credit problems? 
15.Is there a correlation between the number of 
credit problems and the current credit balance? 
16.What is the distribution of current loan 
amounts across different home ownership types? 
17.How does the annual income vary with the 
years in the current job? 
18.Is there a correlation between the current loan 
amount and the monthly debt? 
19.What is the average monthly debt for each 
home ownership type? 
20.How does the credit score vary with the 
number of open accounts? 
21.What is the distribution of credit scores across 
different loan statuses? 
22.Is there a correlation between the current loan 
amount and the years of credit history? 
23.How does the monthly debt vary with the 
number of credit problems? 
24.What is the average current loan amount for 
each purpose of loan? 
25.How does the credit score vary with the 
current credit balance? 
26.Is there a correlation between the annual 
income and the current credit balance? 
27.What is the distribution of annual income 
across different terms (short-term vs. long-term)? 
28.How does the credit score vary with the 
number of credit problems? 
29.Is there a correlation between the current loan 
amount and the number of credit problems? 
30.What is the relationship between the number 
of open accounts and the years of credit history?
# Out:
#   Cell In[7], line 5
#     1.What is the average current loan amount for
#      ^
# SyntaxError: invalid decimal literal

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %%
'''1.What is the average current loan amount for 
each loan status?'''
df.groupby(by='Loan Status')['Current Loan Amount'].mean()
# Out:
# Loan Status
# Charged Off    3.249752e+05
# Fully Paid     1.510694e+07
# Name: Current Loan Amount, dtype: float64

# %%
'''2.How does the credit score vary with the annual 
income? '''
df.groupby(by='Credit Score')['Annual Income'].sum()
# Out:
# Credit Score
# 585.0     42033605.0
# 586.0      9250777.0
# 587.0     17523529.0
# 588.0     33569371.0
# 589.0      8643727.0
#              ...
# 7470.0    68043085.0
# 7480.0    57425961.0
# 7490.0    36337348.0
# 7500.0    32971441.0
# 7510.0     8676844.0
# Name: Annual Income, Length: 324, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Scatter plot to visualize the relationship
plt.figure(figsize=(10, 6))
plt.scatter(df["Annual Income"], df["Credit Score"], alpha=0.5, color="blue")
plt.title("Relationship Between Annual Income and Credit Score")
plt.xlabel("Annual Income")
plt.ylabel("Credit Score")
plt.grid(True)
plt.show()

# Optional: Analyze trends by income ranges
income_bins = pd.cut(df["Annual Income"], bins=5)  # Divide annual income into 5 bins
average_credit_score_by_income = df.groupby(income_bins)["Credit Score"].mean().reset_index()

print("Average Credit Score by Income Range:")
print(average_credit_score_by_income)
# Out:
# Average Credit Score by Income Range:
#                 Annual Income  Credit Score
# 0    (-88853.766, 33172780.2]   1076.383801
# 1    (33172780.2, 66268933.4]    747.000000
# 2    (66268933.4, 99365086.6]           NaN
# 3   (99365086.6, 132461239.8]           NaN
# 4  (132461239.8, 165557393.0]   7250.000000
# C:\Users\PRAMOD\AppData\Local\Temp\ipykernel_35356\624445082.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_credit_score_by_income = df.groupby(income_bins)["Credit Score"].mean().reset_index()

# %%
'''3.Is there a correlation between the number of 
open accounts and the current credit balance? '''
import seaborn as sns
sns.scatterplot(data=df,x='Current Credit Balance',y='Number of Open Accounts')
# Out:
# <Axes: xlabel='Current Credit Balance', ylabel='Number of Open Accounts'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Calculate the correlation coefficient
correlation = df["Number of Open Accounts"].corr(df["Current Credit Balance"])
print(f"Correlation between Number of Open Accounts and Current Credit Balance: {correlation:.2f}")

# Scatter plot to visualize the relationship
plt.figure(figsize=(10, 6))
plt.scatter(df["Number of Open Accounts"], df["Current Credit Balance"], alpha=0.5, color="purple")
plt.title("Relationship Between Number of Open Accounts and Current Credit Balance")
plt.xlabel("Number of Open Accounts")
plt.ylabel("Current Credit Balance")
plt.grid(True)
plt.show()
# Out:
# Correlation between Number of Open Accounts and Current Credit Balance: 0.23

# %%
#4.What is the distribution of credit scores across different home ownership types?
df.groupby(by = 'Home Ownership')['Credit Score'].sum()
# Out:
# Home Ownership
# HaveMortgage       177081.0
# Home Mortgage    40869660.0
# Own Home          8135507.0
# Rent             37844921.0
# Name: Credit Score, dtype: float64

# %%
sns.scatterplot(data=df,x='Home Ownership',y='Credit Score')
# Out:
# <Axes: xlabel='Home Ownership', ylabel='Credit Score'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Box plot to show the distribution of credit scores by home ownership type
plt.figure(figsize=(10, 6))
df.boxplot(column="Credit Score", by="Home Ownership", grid=False)
plt.title("Distribution of Credit Scores Across Home Ownership Types")
plt.suptitle("")  # Remove the automatic title
plt.xlabel("Home Ownership")
plt.ylabel("Credit Score")
plt.xticks(rotation=45)
plt.show()

# %%
#5.How does the annual income differ for different purposes of loans?
df.groupby('Purpose')['Annual Income'].sum()
# Out:
# Purpose
# Business Loan           2.029753e+09
# Buy House               8.448171e+08
# Buy a Car               1.249641e+09
# Debt Consolidation      8.626302e+10
# Educational Expenses    8.782621e+07
# Home Improvements       7.870304e+09
# Medical Bills           1.297953e+09
# Other                   3.562781e+09
# Take a Trip             5.806718e+08
# major_purchase          4.034725e+08
# moving                  1.989219e+08
# other                   6.451905e+09
# renewable_energy        1.178992e+07
# small_business          3.621048e+08
# vacation                8.433614e+07
# wedding                 1.288525e+08
# Name: Annual Income, dtype: float64

# %%
sns.scatterplot(data=df,x='Purpose',y='Annual Income')
# Out:
# <Axes: xlabel='Purpose', ylabel='Annual Income'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Box plot to show the distribution of annual income by loan purpose
plt.figure(figsize=(12, 6))
df.boxplot(column="Annual Income", by="Purpose", grid=False)
plt.title("Distribution of Annual Income by Loan Purpose")
plt.suptitle("")  # Remove the automatic title
plt.xlabel("Loan Purpose")
plt.ylabel("Annual Income")
plt.xticks(rotation=45)
plt.show()

# %%
#6.What is the average monthly debt for each term (short-term vs. long-term)?
df.groupby(by='Term')['Monthly Debt'].mean()
# Out:
# Term
# Long Term     21585.664968
# Short Term    17274.158442
# Name: Monthly Debt, dtype: float64

# %%
import pandas as pd

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Group by "Term" and calculate the average "Monthly Debt"
average_monthly_debt = df.groupby("Term")["Monthly Debt"].mean().reset_index()

# Rename the column for clarity
average_monthly_debt = average_monthly_debt.rename(columns={"Monthly Debt": "Average Monthly Debt"})

# Display the result
print(average_monthly_debt)
# Out:
#          Term  Average Monthly Debt
# 0   Long Term          21585.664968
# 1  Short Term          17274.158442

# %%
#7.Is there a correlation between years of credit history and the current credit balance?
sns.scatterplot(data=df,x='Years of Credit History',y='Current Credit Balance')
# Out:
# <Axes: xlabel='Years of Credit History', ylabel='Current Credit Balance'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Calculate the correlation coefficient between "Years of Credit History" and "Current Credit Balance"
correlation = df["Years of Credit History"].corr(df["Current Credit Balance"])
print(f"Correlation between Years of Credit History and Current Credit Balance: {correlation:.2f}")

# Scatter plot to visualize the relationship
plt.figure(figsize=(10, 6))
plt.scatter(df["Years of Credit History"], df["Current Credit Balance"], alpha=0.5, color="green")
plt.title("Relationship Between Years of Credit History and Current Credit Balance")
plt.xlabel("Years of Credit History")
plt.ylabel("Current Credit Balance")
plt.grid(True)
plt.show()
# Out:
# Correlation between Years of Credit History and Current Credit Balance: 0.21

# %%
#8.How does the credit score vary with the years in the current job?******************************************************
df.groupby(by='Years in current job')['Credit Score'].sum()
# Out:
# Years in current job
# 1 year        5811980.0
# 10+ years    26787599.0
# 2 years       7867323.0
# 3 years       7133806.0
# 4 years       5102010.0
# 5 years       5777325.0
# 6 years       5044588.0
# 7 years       5044234.0
# 8 years       3956660.0
# 9 years       3425077.0
# < 1 year      7055383.0
# Name: Credit Score, dtype: float64

# %%
#9.What is the relationship between the number of credit problems and the number of open accounts?
sns.scatterplot(data=df,x='Number of Credit Problems',y='Number of Open Accounts')
# Out:
# <Axes: xlabel='Number of Credit Problems', ylabel='Number of Open Accounts'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Calculate the correlation coefficient between "Number of Credit Problems" and "Number of Open Accounts"
correlation = df["Number of Credit Problems"].corr(df["Number of Open Accounts"])
print(f"Correlation between Number of Credit Problems and Number of Open Accounts: {correlation:.2f}")

# Scatter plot to visualize the relationship
plt.figure(figsize=(10, 6))
plt.scatter(df["Number of Credit Problems"], df["Number of Open Accounts"], alpha=0.5, color="blue")
plt.title("Relationship Between Number of Credit Problems and Number of Open Accounts")
plt.xlabel("Number of Credit Problems")
plt.ylabel("Number of Open Accounts")
plt.grid(True)
plt.show()
# Out:
# Correlation between Number of Credit Problems and Number of Open Accounts: -0.01

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Box plot to show the distribution of annual income by loan status
plt.figure(figsize=(12, 6))
df.boxplot(column="Annual Income", by="Loan Status", grid=False)
plt.title("Distribution of Annual Income Across Loan Statuses")
plt.suptitle("")  # Remove the automatic title
plt.xlabel("Loan Status")
plt.ylabel("Annual Income")
plt.xticks(rotation=45)
plt.show()

# Optional: You could also use histograms to show the frequency distribution for each loan status
plt.figure(figsize=(12, 6))
df[df["Loan Status"] == "Approved"]["Annual Income"].hist(alpha=0.5, label="Approved", bins=30, color="blue")
df[df["Loan Status"] == "Denied"]["Annual Income"].hist(alpha=0.5, label="Denied", bins=30, color="red")
plt.title("Histogram of Annual Income Across Loan Statuses")
plt.xlabel("Annual Income")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
#11.Is there a correlation between the current loan amount and the number of open accounts?
sns.scatterplot(data=df,x='Current Loan Amount',y='Number of Open Accounts')
# Out:
# <Axes: xlabel='Current Loan Amount', ylabel='Number of Open Accounts'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual data if not already loaded as df)
# df = pd.DataFrame(...)

# Calculate the correlation coefficient between "Current Loan Amount" and "Number of Open Accounts"
correlation = df["Current Loan Amount"].corr(df["Number of Open Accounts"])
print(f"Correlation between Current Loan Amount and Number of Open Accounts: {correlation:.2f}")

# Scatter plot to visualize the relationship
plt.figure(figsize=(10, 6))
plt.scatter(df["Current Loan Amount"], df["Number of Open Accounts"], alpha=0.5, color="purple")
plt.title("Relationship Between Current Loan Amount and Number of Open Accounts")
plt.xlabel("Current Loan Amount")
plt.ylabel("Number of Open Accounts")
plt.grid(True)
plt.show()
# Out:
# Correlation between Current Loan Amount and Number of Open Accounts: 0.00

# %%
#12.How does the monthly debt vary with the years of credit history?
sns.scatterplot(data=df,x='Years of Credit History',y='Monthly Debt')
# Out:
# <Axes: xlabel='Years of Credit History', ylabel='Monthly Debt'>

# %%
#13.What is the average annual income for each purpose of loan?
df.groupby(by='Purpose')['Annual Income'].mean()
# Out:
# Purpose
# Business Loan           1.591963e+06
# Buy House               1.495251e+06
# Buy a Car               1.220353e+06
# Debt Consolidation      1.362464e+06
# Educational Expenses    1.071051e+06
# Home Improvements       1.667437e+06
# Medical Bills           1.409286e+06
# Other                   1.348516e+06
# Take a Trip             1.219899e+06
# major_purchase          1.430753e+06
# moving                  1.591375e+06
# other                   1.286008e+06
# renewable_energy        1.473740e+06
# small_business          1.547456e+06
# vacation                1.155290e+06
# wedding                 1.464233e+06
# Name: Annual Income, dtype: float64
